# %%
import json
from collections import defaultdict

# %%
with open("countries.geojson", "r") as f:
    data = json.load(f)

# %%
def get_points(geom):
    #geom = d['geometry']
    coords = None
    # Convert polygons to multipolygons, to make our life easier...
    if geom['type'] == "Polygon":
        polys = [geom['coordinates']]
    else:
        polys = geom['coordinates']
        
    points = {
        (p[0], p[1]) 
        for poly in polys
        for something in poly
        for p in something
    }
    return points

# %%
countries_coords = [{"id": c['properties']['SU_A3'],
                     "polygon_coords": get_points(c['geometry'])
                    }
                    for c in data["features"]]

# %%
# countries_test = [d for d in countries_coords if d['id'] in ['FXX', 'ESP']]
# countries_test

# %%
coord_country_map = defaultdict(lambda: [])

# Try just a dumb thing of checking coordinates that occur in other countries' boundaries.
for country in countries_coords:
    c_id = country['id']
    for point in set(country['polygon_coords']):
        coord_country_map[point].append(c_id)

# %%
edges = defaultdict(lambda: set())
for k, v in coord_country_map.items():
    # Go through all pairs of country ids in these points
    for i in range(len(v)-1):
        for j in range(i+1, len(v)):
            edges[v[i]].add(v[j])
            edges[v[j]].add(v[i])

# %%
edges
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'ZWE': {'BWA', 'MOZ', 'NAM', 'ZAF', 'ZMB'},
#              'ZMB': {'AGO', 'BWA', 'COD', 'MOZ', 'MWI', 'NAM', 'TZA', 'ZWE'},
#              'ZAF': {'BWA', 'LSO', 'MOZ', 'NAM', 'SWZ', 'ZWE'},
#              'BWA': {'NAM', 'ZAF', 'ZMB', 'ZWE'},
#              'MOZ': {'MWI', 'SWZ', 'TZA', 'ZAF', 'ZMB', 'ZWE'},
#              'NAM': {'AGO', 'BWA', 'ZAF', 'ZMB', 'ZWE'},
#              'COD': {'AGO',
#               'BDI',
#               'CAF',
#               'COG',
#               'RWA',
#               'SDS',
#               'TZA',
#               'UGA',
#               'ZMB'},
#              'AGO': {'COD', 'COG', 'NAM', 'ZMB'},
#              'TZA': {'BDI', 'COD', 'KEN', 'MOZ', 'MWI', 'RWA', 'UGA', 'ZMB'},
#              'MWI': {'MOZ', 'TZA', 'ZMB'},
#              'YEM': {'OMN', 'SAU'},
#              'SAU': {'ARE', 'IRQ', 'JOR', 'KWT', 'OMN', 'QAT', 'YEM'},
#              'OMN': {'ARE', 'SAU', 'YEM'},
#              'VNM': {'CHN', 'KHM', 'LAO'},
#              'KHM': {'LAO', 'THA', 'VNM'},
#              'LAO': {'CHN', 'KHM', 'MMR', 'THA', 'VNM'},
#              'CHN': {'AFG',
#               'BTN',
#               'HKG',
#               'IND',
#               'KAS',
#               'KAZ',
#               'KGZ',
#               'LAO',
#               'MAC',
#               'MMR',
#               'MNG',
#               'NPL',
#               'PAK',
#               'PRK',
#               'RUS',
#               'TJK',
#               'VNM'},
#              'VEN': {'BRA', 'COL', 'GUY'},
#              'GUY': {'BRA', 'SUR', 'VEN'},
#              'BRA': {'ARG',
#               'BOL',
#               'COL',
#               'GUF',
#               'GUY',
#               'PER',
#               'PRY',
#               'SUR',
#               'URY',
#               'VEN'},
#              'COL': {'BRA', 'ECU', 'PAN', 'PER', 'VEN'},
#              'VAT': {'ITA'},
#              'ITA': {'AUT', 'CHE', 'FXX', 'SMR', 'SVN', 'VAT'},
#              'UZB': {'AFG', 'KAZ', 'KGZ', 'TJK', 'TKM'},
#              'TKM': {'AFG', 'IRN', 'KAZ', 'UZB'},
#              'KAZ': {'CHN', 'KGZ', 'RUS', 'TKM', 'UZB'},
#              'KGZ': {'CHN', 'KAZ', 'TJK', 'UZB'},
#              'TJK': {'AFG', 'CHN', 'KGZ', 'UZB'},
#              'AFG': {'CHN', 'IRN', 'PAK', 'TJK', 'TKM', 'UZB'},
#              'URY': {'ARG', 'BRA'},
#              'ARG': {'BOL', 'BRA', 'CHL', 'PRY', 'URY'},
#              'USA': {'CAN', 'MEX'},
#              'CAN': {'USA'},
#              'MEX': {'BLZ', 'GTM', 'USA'},
#              'GBR': {'IRL'},
#              'IRL': {'GBR'},
#              'ARE': {'OMN', 'SAU'},
#              'UKR': {'BLR', 'HUN', 'MDA', 'POL', 'ROU', 'RUS', 'SVK'},
#              'RUS': {'AZE',
#               'BLR',
#               'CHN',
#               'EST',
#               'FIN',
#               'GEO',
#               'KAZ',
#               'LTU',
#               'LVA',
#               'MNG',
#               'NOR',
#               'POL',
#               'PRK',
#               'UKR'},
#              'POL': {'BLR', 'CZE', 'DEU', 'LTU', 'RUS', 'SVK', 'UKR'},
#              'BLR': {'LTU', 'LVA', 'POL', 'RUS', 'UKR'},
#              'MDA': {'ROU', 'UKR'},
#              'ROU': {'BGR', 'HUN', 'MDA', 'SRB', 'UKR'},
#              'HUN': {'AUT', 'HRV', 'ROU', 'SRB', 'SVK', 'SVN', 'UKR'},
#              'SVK': {'AUT', 'CZE', 'HUN', 'POL', 'UKR'},
#              'UGA': {'COD', 'KEN', 'RWA', 'SDS', 'TZA'},
#              'KEN': {'ETH', 'SDS', 'SOM', 'TZA', 'UGA'},
#              'SDS': {'CAF', 'COD', 'ETH', 'KEN', 'SDN', 'UGA'},
#              'RWA': {'BDI', 'COD', 'TZA', 'UGA'},
#              'IRN': {'AFG', 'ARM', 'AZE', 'IRQ', 'PAK', 'TKM', 'TUR'},
#              'TUR': {'ARM', 'AZE', 'BGR', 'GEO', 'GRC', 'IRN', 'IRQ', 'SYR'},
#              'SYR': {'IRQ', 'ISR', 'JOR', 'LBN', 'TUR'},
#              'GRC': {'ALB', 'BGR', 'MKD', 'TUR'},
#              'BGR': {'GRC', 'MKD', 'ROU', 'SRB', 'TUR'},
#              'IRQ': {'IRN', 'JOR', 'KWT', 'SAU', 'SYR', 'TUR'},
#              'ARM': {'AZE', 'GEO', 'IRN', 'TUR'},
#              'GEO': {'ARM', 'AZE', 'RUS', 'TUR'},
#              'AZE': {'ARM', 'GEO', 'IRN', 'RUS', 'TUR'},
#              'TUN': {'DZA', 'LBY'},
#              'LBY': {'DZA', 'EGY', 'NER', 'SDN', 'TCD', 'TUN'},
#              'DZA': {'LBY', 'MAR', 'MLI', 'MRT', 'NER', 'SAH', 'TUN'},
#              'TGO': {'BEN', 'BFA', 'GHA'},
#              'GHA': {'BFA', 'CIV', 'TGO'},
#              'BEN': {'BFA', 'NER', 'NGA', 'TGO'},
#              'BFA': {'BEN', 'CIV', 'GHA', 'MLI', 'NER', 'TGO'},
#              'TLS': {'IDN'},
#              'IDN': {'MYS', 'PN1', 'TLS'},
#              'THA': {'KHM', 'LAO', 'MMR', 'MYS'},
#              'MYS': {'BRN', 'IDN', 'THA'},
#              'MMR': {'BGD', 'CHN', 'IND', 'LAO', 'THA'},
#              'BDI': {'COD', 'RWA', 'TZA'},
#              'LBN': {'ISR', 'SYR'},
#              'JOR': {'IRQ', 'ISR', 'PSX', 'SAU', 'SYR'},
#              'ISR': {'EGY', 'JOR', 'LBN', 'PSX', 'SYR'},
#              'CHE': {'AUT', 'DEU', 'FXX', 'ITA', 'LIE'},
#              'FXX': {'AND', 'BEL', 'CHE', 'DEU', 'ESP', 'ITA', 'LUX', 'MCO'},
#              'AUT': {'CHE', 'CZE', 'DEU', 'HUN', 'ITA', 'LIE', 'SVK', 'SVN'},
#              'DEU': {'AUT',
#               'BEL',
#               'CHE',
#               'CZE',
#               'DNK',
#               'FXX',
#               'LUX',
#               'NLD',
#               'POL'},
#              'LIE': {'AUT', 'CHE'},
#              'SWE': {'FIN', 'NOR'},
#              'NOR': {'FIN', 'RUS', 'SWE'},
#              'FIN': {'NOR', 'RUS', 'SWE'},
#              'SWZ': {'MOZ', 'ZAF'},
#              'SUR': {'BRA', 'GUF', 'GUY'},
#              'GUF': {'BRA', 'SUR'},
#              'CAF': {'CMR', 'COD', 'COG', 'SDN', 'SDS', 'TCD'},
#              'SDN': {'CAF', 'EGY', 'ERI', 'ETH', 'LBY', 'SDS', 'TCD'},
#              'ETH': {'DJI', 'ERI', 'KEN', 'SDN', 'SDS', 'SOL', 'SOM'},
#              'EGY': {'ISR', 'LBY', 'PSX', 'SDN'},
#              'TCD': {'CAF', 'CMR', 'LBY', 'NER', 'NGA', 'SDN'},
#              'ERI': {'DJI', 'ETH', 'SDN'},
#              'ESP': {'AND', 'FXX', 'PR1'},
#              'PR1': {'ESP'},
#              'AND': {'ESP', 'FXX'},
#              'KOR': {'PRK'},
#              'PRK': {'CHN', 'KOR', 'RUS'},
#              'LSO': {'ZAF'},
#              'SOM': {'ETH', 'KEN', 'SOL'},
#              'SOL': {'DJI', 'ETH', 'SOM'},
#              'DJI': {'ERI', 'ETH', 'SOL'},
#              'CZE': {'AUT', 'DEU', 'POL', 'SVK'},
#              'SVN': {'AUT', 'HRV', 'HUN', 'ITA'},
#              'HRV': {'BIH', 'HUN', 'MNE', 'SRB', 'SVN'},
#              'SLE': {'GIN', 'LBR'},
#              'LBR': {'CIV', 'GIN', 'SLE'},
#              'GIN': {'CIV', 'GNB', 'LBR', 'MLI', 'SEN', 'SLE'},
#              'SRB': {'BGR', 'BIH', 'HRV', 'HUN', 'KOS', 'MKD', 'MNE', 'ROU'},
#              'MKD': {'ALB', 'BGR', 'GRC', 'KOS', 'SRB'},
#              'KOS': {'ALB', 'MKD', 'MNE', 'SRB'},
#              'MNE': {'ALB', 'BIH', 'HRV', 'KOS', 'SRB'},
#              'BIH': {'HRV', 'MNE', 'SRB'},
#              'SEN': {'GIN', 'GMB', 'GNB', 'MLI', 'MRT'},
#              'GMB': {'SEN'},
#              'MLI': {'BFA', 'CIV', 'DZA', 'GIN', 'MRT', 'NER', 'SEN'},
#              'MRT': {'DZA', 'MLI', 'SAH', 'SEN'},
#              'GNB': {'GIN', 'SEN'},
#              'KWT': {'IRQ', 'SAU'},
#              'QAT': {'SAU'},
#              'SMR': {'ITA'},
#              'MNG': {'CHN', 'RUS'},
#              'EST': {'LVA', 'RUS'},
#              'LVA': {'BLR', 'EST', 'LTU', 'RUS'},
#              'LTU': {'BLR', 'LVA', 'POL', 'RUS'},
#              'PER': {'BOL', 'BRA', 'CHL', 'COL', 'ECU'},
#              'ECU': {'COL', 'PER'},
#              'BOL': {'ARG', 'BRA', 'CHL', 'PER', 'PRY'},
#              'CHL': {'ARG', 'BOL', 'PER'},
#              'PRY': {'ARG', 'BOL', 'BRA'},
#              'PN1': {'IDN'},
#              'PAN': {'COL', 'CRI'},
#              'CRI': {'NIC', 'PAN'},
#              'PAK': {'AFG', 'CHN', 'IND', 'IRN', 'KAS'},
#              'IND': {'BGD', 'BTN', 'CHN', 'KAS', 'MMR', 'NPL', 'PAK'},
#              'KAS': {'CHN', 'IND', 'PAK'},
#              'NGA': {'BEN', 'CMR', 'NER', 'TCD'},
#              'NER': {'BEN', 'BFA', 'DZA', 'LBY', 'MLI', 'NGA', 'TCD'},
#              'CMR': {'CAF', 'COG', 'GAB', 'GNQ', 'NGA', 'TCD'},
#              'NIC': {'CRI', 'HND'},
#              'HND': {'GTM', 'NIC', 'SLV'},
#              'NPL': {'CHN', 'IND'},
#              'MAR': {'DZA', 'SAH'},
#              'SAH': {'DZA', 'MAR', 'MRT'},
#              'ALB': {'GRC', 'KOS', 'MKD', 'MNE'},
#              'MCO': {'FXX'},
#              'GTM': {'BLZ', 'HND', 'MEX', 'SLV'},
#              'BLZ': {'GTM', 'MEX'},
#              'CIV': {'BFA', 'GHA', 'GIN', 'LBR', 'MLI'},
#              'BRN': {'MYS'},
#              'LUX': {'BEL', 'DEU', 'FXX'},
#              'BEL': {'DEU', 'FXX', 'LUX', 'NLD'},
#              'PSX': {'EGY', 'ISR', 'JOR'},
#              'BGD': {'IND', 'MMR'},
#              'BTN': {'CHN', 'IND'},
#              'SLV': {'GTM', 'HND'},
#              'HTI': {'DOM'},
#              'DOM': {'HTI'},
#              'DNK': {'DEU'},
#              'NLD': {'BEL', 'DEU'},
#              'GAB': {'CMR', 'COG', 'GNQ'},
#              'COG': {'AGO', 'CAF', 'CMR', 'COD', 'GAB'},
#              'GNQ': {'CMR', 'GAB'},
#              'MAF': {'SXM'},
#              'SXM': {'MAF'},
#              'CYN': {'CYP'},
#              'CYP': {'CYN'},
#              'MAC': {'CHN'},
#              'HKG': {'CHN'}})

# %%
# Convert sets to lists.
edges_write = {
    k: list(vals) for k, vals in edges.items()
}

# write to file!
with open("country_adjacency.json", "w") as f:
    f.write(json.dumps(edges_write))
