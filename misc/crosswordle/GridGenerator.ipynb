# %%
import scipy
from sklearn.neighbors import KDTree
from scipy.spatial import distance 
import numpy as np
from numpy.random import default_rng
import pandas as pd
from tqdm import tqdm
from collections import defaultdict
import random
import copy
import functools
import itertools
import json

# %%
# Import google common words..!

words_list = []
with open('google-10000-english/google-10000-english-no-swears.txt') as f:
    for line in f:
        word = line.strip()
        if word:
            words_list.append(word)

len(words_list)
# Out:
# 9894

# %%
words_list[9888]
# Out:
# 'swaziland'

# %%
[w for w in words_list if 'new' in w]
# Out:
# ['new',
#  'news',
#  'newsletter',
#  'newsletters',
#  'knew',
#  'newspaper',
#  'newest',
#  'newly',
#  'newspapers',
#  'renewal',
#  'newton',
#  'newport',
#  'newcastle',
#  'newbie',
#  'newer',
#  'renew',
#  'renewable',
#  'newfoundland',
#  'newark',
#  'newman']

# %%
# Strip down to common ones
print(words_list.index('eau'))
words_list = words_list[:4000]
# Out:
# 8479

# %%
scrabble_words_list = []
with open('Collins Scrabble Words (2019).txt') as f:
    next(f) # Remove first line
    for line in f:
        word = line.strip().lower()
        if word:
            scrabble_words_list.append(word)
            
len(scrabble_words_list)
# Out:
# 279496

# %%
# Find overlap!
words_list = set.intersection(set(words_list), set(scrabble_words_list))
len(words_list)
# Out:
# 8347

# %%
# Create guess list... This contains far more words.
guesses_list = [w for w in scrabble_words_list if len(w) <= 6]
print(len(guesses_list))

with open('crosswordle_page/guess_list.js', 'w') as f:
    s = json.dumps(guesses_list)
    f.write("var GUESS_LIST = new Set(");
    f.write(s)
    f.write(");")
# Out:
# 43117

# %%
set(words_list) - set(scrabble_words_list)
# Out:
# {'lexmark',
#  've',
#  'url',
#  'eden',
#  'phil',
#  'plugins',
#  'gzip',
#  'msie',
#  'bhutan',
#  'usgs',
#  'l',
#  'lithuania',
#  'tgp',
#  'cc',
#  'dk',
#  'wv',
#  'zimbabwe',
#  'tracy',
#  'december',
#  'seattle',
#  'tampa',
#  'anthony',
#  'xl',
#  'wifi',
#  'ist',
#  'diego',
#  'september',
#  'marcus',
#  'harold',
#  'henderson',
#  'kb',
#  's',
#  'phillips',
#  'lexington',
#  'nottingham',
#  'val',
#  'trackbacks',
#  'hispanic',
#  'rp',
#  'southampton',
#  'rj',
#  'pm',
#  'japanese',
#  'taiwan',
#  'darwin',
#  'struct',
#  'rochester',
#  'istanbul',
#  'isaac',
#  'mx',
#  'belkin',
#  'ts',
#  'gr',
#  'fp',
#  'vancouver',
#  'sb',
#  'cruz',
#  'cn',
#  'bermuda',
#  'wallace',
#  'sk',
#  'mj',
#  'scottish',
#  'lc',
#  'jefferson',
#  'inf',
#  'fiji',
#  'february',
#  'a',
#  'berkeley',
#  'joyce',
#  'aberdeen',
#  'gary',
#  'erp',
#  'deutschland',
#  'irc',
#  'montreal',
#  'irs',
#  'qc',
#  'ww',
#  'mitchell',
#  'cio',
#  'x',
#  'milton',
#  'jr',
#  'invision',
#  'ambien',
#  'ppc',
#  'linda',
#  'saturn',
#  'fw',
#  'americans',
#  'jpg',
#  'nba',
#  'nec',
#  'freebsd',
#  'samsung',
#  'gmc',
#  'kenya',
#  'cornell',
#  'fujitsu',
#  'singapore',
#  'ic',
#  'katie',
#  'holdem',
#  'wednesday',
#  'clinton',
#  'lincoln',
#  'mtv',
#  'mozilla',
#  'caribbean',
#  'plc',
#  'scsi',
#  'transexuales',
#  'czech',
#  'nsw',
#  'massachusetts',
#  'oman',
#  'aud',
#  'thu',
#  'bk',
#  'bb',
#  'ri',
#  'ul',
#  'louisville',
#  'mhz',
#  'md',
#  'mw',
#  'hamilton',
#  'baltimore',
#  'wisconsin',
#  'ie',
#  'ps',
#  'italiano',
#  'lopez',
#  'ro',
#  'suse',
#  'stuart',
#  'pb',
#  'algeria',
#  'kelkoo',
#  'goto',
#  'chen',
#  'mauritius',
#  'rf',
#  'hungary',
#  'vernon',
#  'tion',
#  'wp',
#  'pf',
#  'thinkpad',
#  'aus',
#  'isa',
#  'wto',
#  'rna',
#  'vietnamese',
#  'leonard',
#  'bt',
#  'bmw',
#  'yugoslavia',
#  'faq',
#  'mozambique',
#  'vcr',
#  'chan',
#  'louise',
#  'verizon',
#  'phys',
#  'sn',
#  'ati',
#  'pl',
#  'slovenia',
#  'm',
#  'arg',
#  'fl',
#  'km',
#  'plugin',
#  'philip',
#  'nvidia',
#  'munich',
#  'clark',
#  'exp',
#  'hampton',
#  'albania',
#  'wiley',
#  'std',
#  'sw',
#  'fx',
#  'carlo',
#  'oklahoma',
#  'vincent',
#  'hiv',
#  'philadelphia',
#  'joel',
#  'jessica',
#  'wordpress',
#  'andy',
#  'casio',
#  'postposted',
#  'pdf',
#  'tp',
#  'subaru',
#  'mazda',
#  'disney',
#  'ca',
#  'und',
#  'hp',
#  'dl',
#  'ata',
#  'netscape',
#  'ian',
#  'curtis',
#  'sunday',
#  'indonesia',
#  'mins',
#  'foto',
#  'sagem',
#  'rpm',
#  'gp',
#  'rn',
#  'aruba',
#  'thursday',
#  'irish',
#  'columbia',
#  'sacramento',
#  'shakespeare',
#  'deutsch',
#  'fbi',
#  'aol',
#  'wi',
#  'trinidad',
#  'hc',
#  'denver',
#  'london',
#  'gps',
#  'naples',
#  'smtp',
#  'frederick',
#  'campbell',
#  'salem',
#  'r',
#  'nicaragua',
#  'fu',
#  'baghdad',
#  'mrna',
#  'pci',
#  'australian',
#  'cv',
#  'ste',
#  'kevin',
#  'wesley',
#  'usa',
#  'jim',
#  'netherlands',
#  'catherine',
#  'gordon',
#  'mai',
#  'worldcat',
#  'richards',
#  'newcastle',
#  'delaware',
#  'ind',
#  'david',
#  'saskatchewan',
#  'biol',
#  'wyoming',
#  'roland',
#  'mn',
#  'olympus',
#  'jamaica',
#  'idaho',
#  'alex',
#  'pakistan',
#  'zdnet',
#  'tulsa',
#  'samoa',
#  'doug',
#  'harris',
#  'proc',
#  'cst',
#  'mr',
#  'cd',
#  'antigua',
#  'cadillac',
#  'tokyo',
#  'latvia',
#  'rc',
#  'alabama',
#  'c',
#  'alot',
#  'hartford',
#  'maldives',
#  'ltd',
#  'lycos',
#  'turkish',
#  'barbados',
#  'claire',
#  'erik',
#  'iran',
#  'pp',
#  'barnes',
#  'iraq',
#  'trembl',
#  'stanford',
#  'edinburgh',
#  'albany',
#  'finland',
#  'peru',
#  'tu',
#  'pcs',
#  'samuel',
#  'indian',
#  'ft',
#  'european',
#  'childrens',
#  'ui',
#  'cir',
#  'php',
#  'volkswagen',
#  'newport',
#  'bp',
#  'ext',
#  'rh',
#  'korea',
#  'ukraine',
#  'hans',
#  'gamecube',
#  'pichunter',
#  'celtic',
#  'indianapolis',
#  'brighton',
#  'joshua',
#  'propecia',
#  'adrian',
#  'una',
#  'germany',
#  'oclc',
#  'andrews',
#  'karen',
#  'jan',
#  'obj',
#  'dept',
#  'kenny',
#  'tr',
#  'dennis',
#  'owen',
#  'oakland',
#  'romania',
#  'tcp',
#  'matthew',
#  'hr',
#  'deborah',
#  'simpson',
#  'dayton',
#  'y',
#  'usd',
#  'boc',
#  'treo',
#  'slovak',
#  'str',
#  'barcelona',
#  'kathy',
#  'fc',
#  'russian',
#  'vbulletin',
#  'ccd',
#  'rio',
#  'pk',
#  'ict',
#  'african',
#  'uruguay',
#  'qty',
#  'eval',
#  'hudson',
#  'ce',
#  'tennessee',
#  'vatican',
#  'paraguay',
#  'mitsubishi',
#  'moore',
#  'islamic',
#  'sao',
#  'vip',
#  'liechtenstein',
#  'mia',
#  'blair',
#  'cw',
#  'sa',
#  'avg',
#  'tue',
#  'antarctica',
#  'peterson',
#  'harley',
#  'isbn',
#  'british',
#  'budapest',
#  'miami',
#  'adidas',
#  'todd',
#  'utc',
#  'illinois',
#  'argentina',
#  'av',
#  'intl',
#  'mysql',
#  'ncaa',
#  'fraser',
#  'syracuse',
#  'charles',
#  'pdas',
#  'wc',
#  'caroline',
#  'salvador',
#  'dsl',
#  'sp',
#  'dylan',
#  'patricia',
#  'uri',
#  'sq',
#  'eq',
#  'pt',
#  'bahamas',
#  'prague',
#  'dealtime',
#  'uzbekistan',
#  'robinson',
#  'ph',
#  'hilton',
#  'iv',
#  'carroll',
#  'houston',
#  'qatar',
#  'robbie',
#  'cia',
#  'prix',
#  'chester',
#  'ct',
#  'acdbentity',
#  'hewlett',
#  'halifax',
#  'mumbai',
#  'gc',
#  'nasa',
#  'nebraska',
#  'nascar',
#  'singh',
#  'findlaw',
#  'fioricet',
#  'oem',
#  'lanka',
#  'paypal',
#  'rb',
#  'cb',
#  'vpn',
#  'calgary',
#  'nj',
#  'leslie',
#  'laos',
#  'tim',
#  'gras',
#  'tm',
#  'nato',
#  'phpbb',
#  'mexican',
#  'wa',
#  'nigeria',
#  'chrysler',
#  'pittsburgh',
#  'annie',
#  'canadian',
#  'crawford',
#  'simpsons',
#  'soa',
#  'johnston',
#  'allan',
#  'dd',
#  'botswana',
#  'westminster',
#  'der',
#  'toyota',
#  'se',
#  'd',
#  'playstation',
#  'uc',
#  'muslims',
#  'asin',
#  'rhode',
#  'inc',
#  'bs',
#  'incl',
#  'etc',
#  'oz',
#  'dominican',
#  'viewpicture',
#  'img',
#  'julie',
#  'lauderdale',
#  'hitachi',
#  'com',
#  'cf',
#  'dc',
#  'austin',
#  'ml',
#  'duncan',
#  'washington',
#  'cz',
#  'liz',
#  'christ',
#  'klein',
#  'abc',
#  'rm',
#  'melbourne',
#  'ferrari',
#  'css',
#  'livecam',
#  'italian',
#  'susan',
#  'roberts',
#  'shannon',
#  'espn',
#  'christine',
#  'hyundai',
#  'ceo',
#  'wendy',
#  'webshots',
#  'hansen',
#  'gpl',
#  'tft',
#  'ii',
#  'dr',
#  'gbp',
#  'zealand',
#  'puerto',
#  'abraham',
#  'xanax',
#  'bosnia',
#  'milan',
#  'robertson',
#  'acm',
#  'stockholm',
#  'indonesian',
#  'missouri',
#  'wayne',
#  'nb',
#  'fr',
#  'ol',
#  'zus',
#  'norwegian',
#  'bbs',
#  'plymouth',
#  'tt',
#  'll',
#  'ss',
#  'guyana',
#  'chelsea',
#  'malta',
#  'vietnam',
#  'issn',
#  'watson',
#  'eos',
#  'approx',
#  'paxil',
#  'mp',
#  'jvc',
#  'dat',
#  'prozac',
#  'sg',
#  'dana',
#  'eugene',
#  'eur',
#  'og',
#  'pda',
#  'changelog',
#  'rome',
#  'cambodia',
#  'oregon',
#  'dicke',
#  'louisiana',
#  'phentermine',
#  'nathan',
#  'nicholas',
#  'france',
#  'ip',
#  'jerusalem',
#  'usc',
#  'kingston',
#  'walt',
#  'hopkins',
#  'kansas',
#  'chicago',
#  'starsmerchant',
#  'lcd',
#  'europe',
#  'ssl',
#  'sf',
#  'f',
#  'tobago',
#  'vermont',
#  'sussex',
#  'helen',
#  'basename',
#  'rebecca',
#  'brunei',
#  'bahrain',
#  'finnish',
#  'senegal',
#  'une',
#  'volvo',
#  'ron',
#  'indiana',
#  'douglas',
#  'asian',
#  'lol',
#  'janet',
#  'ghz',
#  'edgar',
#  'maui',
#  'jennifer',
#  'shopzilla',
#  'hughes',
#  'src',
#  'cms',
#  'jon',
#  'wm',
#  'connecticut',
#  'wichita',
#  'honduras',
#  'ultram',
#  'stephen',
#  'gibraltar',
#  'belize',
#  'lil',
#  'wx',
#  'gerald',
#  'seo',
#  'ev',
#  'persian',
#  'cds',
#  'iceland',
#  'telecharger',
#  'flickr',
#  'sl',
#  'kruger',
#  'dh',
#  'donald',
#  'diy',
#  'cleveland',
#  'seq',
#  'jewish',
#  'buf',
#  'arthur',
#  'bizrate',
#  'floyd',
#  'britain',
#  'auckland',
#  'rl',
#  'ada',
#  'hampshire',
#  'marilyn',
#  'xbox',
#  'hawaiian',
#  'bangladesh',
#  'nevada',
#  'margaret',
#  'africa',
#  'jacob',
#  'por',
#  'xhtml',
#  'adam',
#  'hindu',
#  'gabriel',
#  'ronald',
#  'mcdonald',
#  'pete',
#  'nextel',
#  'ellis',
#  'zambia',
#  'milwaukee',
#  'venice',
#  'tuesday',
#  'w',
#  'divx',
#  'wikipedia',
#  'howto',
#  'barbara',
#  'american',
#  'i',
#  'lt',
#  'citysearch',
#  'dm',
#  'vg',
#  'santa',
#  'taylor',
#  'hugo',
#  'marco',
#  'april',
#  'sydney',
#  'dvds',
#  'mastercard',
#  'sas',
#  'hz',
#  'carolina',
#  'portsmouth',
#  'marriott',
#  'sarah',
#  'cm',
#  'zu',
#  'lightbox',
#  'monaco',
#  'honolulu',
#  'itunes',
#  'ryan',
#  'olympic',
#  'bluetooth',
#  'g',
#  'britney',
#  'tunisia',
#  'christina',
#  'rv',
#  'z',
#  'bg',
#  'nasdaq',
#  'fda',
#  'ia',
#  'js',
#  'html',
#  'pontiac',
#  'zope',
#  'bradford',
#  'rca',
#  'nike',
#  'notre',
#  'jackie',
#  'pg',
#  'xml',
#  'malawi',
#  'slovakia',
#  'jul',
#  'ln',
#  'cornwall',
#  'mlb',
#  'dna',
#  'rfc',
#  'au',
#  'russell',
#  'memphis',
#  'techrepublic',
#  'dt',
#  'coleman',
#  'azerbaijan',
#  'epinions',
#  'dublin',
#  'california',
#  'asus',
#  'omaha',
#  'pct',
#  'mario',
#  'skype',
#  'womens',
#  'elizabeth',
#  'thats',
#  'clara',
#  'macromedia',
#  'ep',
#  'ieee',
#  'nashville',
#  'dir',
#  'victorian',
#  'windsor',
#  'ascii',
#  'usps',
#  'prev',
#  'looksmart',
#  'microsoft',
#  'th',
#  'du',
#  'ds',
#  'voyeurweb',
#  'br',
#  'blake',
#  'neo',
#  'endif',
#  'utah',
#  'mississippi',
#  'thomson',
#  'edwards',
#  'winston',
#  'jacksonville',
#  'ohio',
#  'nw',
#  'pc',
#  'reid',
#  'ppm',
#  'lexus',
#  'calvin',
#  'hh',
#  'aj',
#  'brazilian',
#  'bl',
#  'asn',
#  'jm',
#  'v',
#  'perth',
#  'athens',
#  'lancaster',
#  'config',
#  'n',
#  'nh',
#  'wishlist',
#  'yn',
#  'mv',
#  'vii',
#  'leo',
#  'malaysia',
#  'albuquerque',
#  'richmond',
#  'cl',
#  'epson',
#  'cpu',
#  'ali',
#  'beatles',
#  'belfast',
#  'andorra',
#  'egypt',
#  'cs',
#  'neil',
#  'zum',
#  'nr',
#  'dave',
#  'mercedes',
#  'cet',
#  'nhl',
#  'marie',
#  'fred',
#  'mpeg',
#  'toshiba',
#  'ty',
#  'loc',
#  'bufing',
#  'msgid',
#  'sku',
#  'monroe',
#  'runtime',
#  'italia',
#  'venezuela',
#  'gdp',
#  'ot',
#  'hotmail',
#  'mph',
#  'hwy',
#  'jeffrey',
#  'fs',
#  'iraqi',
#  'cdna',
#  'yorkshire',
#  'hq',
#  'lucy',
#  'bryan',
#  'nikon',
#  'medline',
#  'beijing',
#  'sd',
#  'lb',
#  'ls',
#  'luis',
#  'reuters',
#  'co',
#  'ht',
#  'october',
#  'jpeg',
#  'hdtv',
#  'nv',
#  'fcc',
#  'dem',
#  'ipod',
#  'llp',
#  'brandon',
#  'dx',
#  'ethiopia',
#  'voyuer',
#  'wav',
#  'toronto',
#  'bd',
#  'pd',
#  'rx',
#  'rss',
#  'kg',
#  'england',
#  'pierre',
#  'minnesota',
#  'ci',
#  'namespace',
#  'essex',
#  'inline',
#  'britannica',
#  'lg',
#  'oct',
#  'mariah',
#  'nissan',
#  'monday',
#  'e',
#  'dont',
#  'lafayette',
#  'sega',
#  'francisco',
#  'rr',
#  'fo',
#  'ld',
#  'tahoe',
#  'ms',
#  'myers',
#  'elliott',
#  'delhi',
#  'crm',
#  'abu',
#  'rg',
#  'isp',
#  'jason',
#  'glenn',
#  'telecommunications',
#  'dv',
#  'somalia',
#  'larry',
#  'croatia',
#  'switzerland',
#  'aaa',
#  'ni',
#  'luxembourg',
#  'des',
#  'gd',
#  'sullivan',
#  'pty',
#  'amd',
#  'characterization',
#  'findarticles',
#  'leeds',
#  'wn',
#  'cincinnati',
#  'greg',
#  'minolta',
#  'fri',
#  'hugh',
#  'vs',
#  'deutsche',
#  'powerpoint',
#  'luther',
#  'wy',
#  'sitemap',
#  'atlanta',
#  'scotland',
#  'syria',
#  'petersburg',
#  'gregory',
#  'gtk',
#  'le',
#  'tc',
#  'gsm',
#  'cambridge',
#  'clarke',
#  'walter',
#  'austria',
#  'forbes',
#  'allen',
#  'eminem',
#  'nicole',
#  'thumbzilla',
#  'bennett',
#  'grenada',
#  'apnic',
#  'norfolk',
#  'ns',
#  'bradley',
#  'hs',
#  'palestinian',
#  'pentium',
#  'nyc',
#  'joan',
#  'cnet',
#  'moldova',
#  'af',
#  'q',
#  'const',
#  'dns',
#  'dg',
#  'ix',
#  'georgia',
#  'edmonton',
#  'marion',
#  'portugal',
#  'nd',
#  'edt',
#  'rwanda',
#  'blvd',
#  'jc',
#  'len',
#  'chris',
#  'gui',
#  'nfl',
#  'mit',
#  'acc',
#  'ellen',
#  ...}

# %%
# import nltk
# # nltk.download('words')
# nltk.download('wordnet')

# %%
# from nltk.corpus import words
# from nltk.corpus import wordnet

# %%
# words = list(wordnet.words())

# def is_word(word):
#     # NOTE: Removing hyphenated words too.
#     return (
#         not any(c in word for c in '-_. \'"0123456789,<>!@#$%^&*({[]})')
#     )
# print(len(words))

# words = [w for w in words if is_word(w)]
# print(len(words))
# # Also convert everything to lower case... Maybe I don't want place names though..??
# words = { w.lower() for w in words }
# print(len(words))

# %%
words_by_length = defaultdict(list)

for w in words_list:
    words_by_length[len(w)].append(w)

# %%
@functools.lru_cache(maxsize=None)
def words_from_constraint(length, position, letter):
    return { w for w in words_by_length[length] if w[position] == letter }

def words_from_constraints(length, constraints):
    if not constraints:
        return words_by_length[length]
    
    sets = (words_from_constraint(length, position, letter)
            for position, letter in constraints)
    
    return set.intersection(*sets)


words_from_constraints(5, [(0, 'a'), (3, 'b')])
# Out:
# {'adobe'}

# %%
# A word is just a list of positions that're covered by that word in the grid.
# Could store 'position', 'direction' but...

# Generate all words in a grid

# | 0,0 | 1,0 | ..
# | 0,1 | 1,1 | ..
#   ..    ..

def get_words_in_grid(size_x, size_y):
    words = []

    for i in range(size_x):
        words.append(
            [(i, j) for j in range(size_y)]
        )

    for j in range(size_y):
        words.append(
            [(i, j) for i in range(size_x)]
        )

    random.shuffle(words)

    return words

words = get_words_in_grid(5, 5)
words
# Out:
# [[(0, 2), (1, 2), (2, 2), (3, 2), (4, 2)],
#  [(2, 0), (2, 1), (2, 2), (2, 3), (2, 4)],
#  [(0, 0), (1, 0), (2, 0), (3, 0), (4, 0)],
#  [(3, 0), (3, 1), (3, 2), (3, 3), (3, 4)],
#  [(0, 3), (1, 3), (2, 3), (3, 3), (4, 3)],
#  [(0, 4), (1, 4), (2, 4), (3, 4), (4, 4)],
#  [(1, 0), (1, 1), (1, 2), (1, 3), (1, 4)],
#  [(4, 0), (4, 1), (4, 2), (4, 3), (4, 4)],
#  [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)],
#  [(0, 0), (0, 1), (0, 2), (0, 3), (0, 4)]]

# %%
rng = default_rng()

# %%
a = list(range(10))

# %%
a[3], a[:3], a[3+1:]
# Out:
# (3, [0, 1, 2], [4, 5, 6, 7, 8, 9])

# %%
# Generate some interesting grids..??

def generate_grid(size_x, size_y, min_word_len=3, spawn_attempts=200):
    size_x = 5
    size_y = 5

    grid = np.array([['_' for i in range(size_x)] for j in range(size_y)])

    for i in range(spawn_attempts):
        # Randomly insert '#'s!
        x, y = rng.integers(size_x), rng.integers(size_y)

        # Will this break anything..?
        def is_valid_word(squares):
            if len(squares) <= 1:
                return True

            if squares[0] == '#':
                return True

            for i in range(min_word_len):
                if i >= len(squares) or squares[i] == '#':
                    return False;

            return True


        if (grid[y, x] != '#'
               and is_valid_word(grid[y, x+1:])
               and is_valid_word(np.flip(grid[y, :x]))
               and is_valid_word(np.flip(grid[:y, x]))
               and is_valid_word(grid[y+1:, x])):

            # Can insert!
            grid[y, x] = '#'
    

grid = generate_grid(5, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-3c76f48c2d0c> in <module>
#      36
#      37
# ---> 38 grid = generate_grid(5, 5)
#
# <ipython-input-27-3c76f48c2d0c> in generate_grid(size_x, size_y, min_word_len, spawn_attempts)
#       9     for i in range(spawn_attempts):
#      10         # Randomly insert '#'s!
# ---> 11         x, y = rng.integers(size_x), rng.integers(size_y)
#      12
#      13         # Will this break anything..?
#
# NameError: name 'rng' is not defined

# %%
# Convert grid to list of words
col_words = []
for i in range(size_x):
    word = []
    for j in range(size_y):
        if grid[j, i] == '_':
            word.append((i, j))
        else:
            # NOTE: May be adding empty words... Deal with it later
            col_words.append(word)
            word = []
    col_words.append(word)
    
row_words = [] 
for j in range(size_y):
    word = []
    for i in range(size_x):
        if grid[j, i] == '_':
            word.append((i, j))
        else:
            # NOTE: May be adding empty words... Deal with it later
            row_words.append(word)
            word = []
    row_words.append(word)
    
    
col_words = [w for w in col_words if len(w) > 1]
row_words = [w for w in row_words if len(w) > 1]

# Intercalate for best performance - most interlocking of words.
words = [x for x in itertools.chain(*itertools.zip_longest(col_words, row_words)) if x is not None]
        
grid, words
# Out:
# (array([['_', '_', '_', '#', '#'],
#         ['_', '#', '_', '_', '_'],
#         ['_', '_', '_', '_', '_'],
#         ['#', '_', '_', '_', '_'],
#         ['_', '_', '_', '#', '#']], dtype='<U1'),
#  [[(0, 0), (0, 1), (0, 2)],
#   [(0, 0), (1, 0), (2, 0)],
#   [(1, 2), (1, 3), (1, 4)],
#   [(2, 1), (3, 1), (4, 1)],
#   [(2, 0), (2, 1), (2, 2), (2, 3), (2, 4)],
#   [(0, 2), (1, 2), (2, 2), (3, 2), (4, 2)],
#   [(3, 1), (3, 2), (3, 3)],
#   [(1, 3), (2, 3), (3, 3), (4, 3)],
#   [(4, 1), (4, 2), (4, 3)],
#   [(0, 4), (1, 4), (2, 4)]])

# %%
def nice_print(grid):
    print('+-' * len(grid[0]) + '+')
    for row in grid:
        print('|' + '|'.join(row) + '|')
        print('+-' * len(row) + '+')
        
    print()

# %%
grid = [[' ' for i in range(size_x)] for j in range(size_y)]
# NOTE: Accessed with grid[y][x]

node_tracker = defaultdict(int)

def dfs(depth):
    node_tracker[depth] += 1
    
    if depth >= len(words):
        yield copy.deepcopy(grid)
        return
        
    # Build constraints for this word.
    new_letters = []
    constraints = []
    for ix, (i,j) in enumerate(words[depth]):
        c = grid[j][i]
        if c == ' ':
            new_letters.append((ix, i, j))
        else:
            constraints.append((ix, c))

#     print(new_letters, constraints, ix)

    # Find words.
    possible_words = words_from_constraints(ix+1, constraints)
    # NOTE: This is making the program way slower!!
#     possible_words = list(possible_words)
#     random.shuffle(possible_words)

    
    #print('found:', len(possible_words), 'possible words')
    #print(ix+1, constraints)
    for w in possible_words:
        # Insert word into grid...
        for ix, i, j in new_letters:
            grid[j][i] = w[ix]
            
        # Recurse
        for ans in dfs(depth + 1):
            yield ans
        
        # Remove word from grid
        for ix, i, j in new_letters:
            grid[j][i] = ' '
      
x = dfs(0)
for i in range(100):
    b = next(x)
    nice_print(b)
    
    js = str([''.join(row) for row in b])
    print(js)
# Out:
# +-+-+-+-+-+
# |t|i|p| | |
# +-+-+-+-+-+
# |e| |r|e|s|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |p|e|r| | |
# +-+-+-+-+-+
#
# ['tip  ', 'e res', 'noise', ' note', 'per  ']
# +-+-+-+-+-+
# |t|i|p| | |
# +-+-+-+-+-+
# |e| |r|e|s|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |h|e|r| | |
# +-+-+-+-+-+
#
# ['tip  ', 'e res', 'noise', ' note', 'her  ']
# +-+-+-+-+-+
# |t|i|p| | |
# +-+-+-+-+-+
# |e| |r|e|f|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |p|e|r| | |
# +-+-+-+-+-+
#
# ['tip  ', 'e ref', 'noise', ' note', 'per  ']
# +-+-+-+-+-+
# |t|i|p| | |
# +-+-+-+-+-+
# |e| |r|e|f|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |h|e|r| | |
# +-+-+-+-+-+
#
# ['tip  ', 'e ref', 'noise', ' note', 'her  ']
# +-+-+-+-+-+
# |t|o|p| | |
# +-+-+-+-+-+
# |e| |r|e|s|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |p|e|r| | |
# +-+-+-+-+-+
#
# ['top  ', 'e res', 'noise', ' note', 'per  ']
# +-+-+-+-+-+
# |t|o|p| | |
# +-+-+-+-+-+
# |e| |r|e|s|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |h|e|r| | |
# +-+-+-+-+-+
#
# ['top  ', 'e res', 'noise', ' note', 'her  ']
# +-+-+-+-+-+
# |t|o|p| | |
# +-+-+-+-+-+
# |e| |r|e|f|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |p|e|r| | |
# +-+-+-+-+-+
#
# ['top  ', 'e ref', 'noise', ' note', 'per  ']
# +-+-+-+-+-+
# |t|o|p| | |
# +-+-+-+-+-+
# |e| |r|e|f|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |n|o|t|e|
# +-+-+-+-+-+
# |h|e|r| | |
# +-+-+-+-+-+
#
# ['top  ', 'e ref', 'noise', ' note', 'her  ']
# +-+-+-+-+-+
# |t|a|b| | |
# +-+-+-+-+-+
# |e| |r|u|n|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |f|e|e|t|
# +-+-+-+-+-+
# |o|f|f| | |
# +-+-+-+-+-+
#
# ['tab  ', 'e run', 'noise', ' feet', 'off  ']
# +-+-+-+-+-+
# |t|e|a| | |
# +-+-+-+-+-+
# |e| |s|p|a|
# +-+-+-+-+-+
# |n|a|k|e|d|
# +-+-+-+-+-+
# | |g|e|t|s|
# +-+-+-+-+-+
# |b|e|d| | |
# +-+-+-+-+-+
#
# ['tea  ', 'e spa', 'naked', ' gets', 'bed  ']
# +-+-+-+-+-+
# |t|e|a| | |
# +-+-+-+-+-+
# |e| |s|p|a|
# +-+-+-+-+-+
# |n|a|k|e|d|
# +-+-+-+-+-+
# | |g|e|t|s|
# +-+-+-+-+-+
# |w|e|d| | |
# +-+-+-+-+-+
#
# ['tea  ', 'e spa', 'naked', ' gets', 'wed  ']
# +-+-+-+-+-+
# |t|e|a| | |
# +-+-+-+-+-+
# |e| |s|p|a|
# +-+-+-+-+-+
# |n|a|k|e|d|
# +-+-+-+-+-+
# | |g|e|t|s|
# +-+-+-+-+-+
# |r|e|d| | |
# +-+-+-+-+-+
#
# ['tea  ', 'e spa', 'naked', ' gets', 'red  ']
# +-+-+-+-+-+
# |t|e|a| | |
# +-+-+-+-+-+
# |e| |s|p|a|
# +-+-+-+-+-+
# |n|a|k|e|d|
# +-+-+-+-+-+
# | |g|e|t|s|
# +-+-+-+-+-+
# |l|e|d| | |
# +-+-+-+-+-+
#
# ['tea  ', 'e spa', 'naked', ' gets', 'led  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |l|e|s| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'les  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |r|e|s| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'res  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'yes  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |b|e|d| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'bed  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |w|e|d| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'wed  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |r|e|d| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'red  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |l|e|d| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' need', 'led  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |l|e|a|d|
# +-+-+-+-+-+
# |a|d|s| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' lead', 'ads  ']
# +-+-+-+-+-+
# |t|e|l| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |l|e|a|d|
# +-+-+-+-+-+
# |a|d|d| | |
# +-+-+-+-+-+
#
# ['tel  ', 'e iso', 'novel', ' lead', 'add  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |b|e|d| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'bed  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |w|e|d| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'wed  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |r|e|d| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'red  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |l|e|d| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'led  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |l|e|s| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'les  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |r|e|s| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'res  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'yes  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |l|e|f|t|
# +-+-+-+-+-+
# |o|l|d| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' left', 'old  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e are', 'names', ' rest', 'its  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |o|u|r|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |u|s|e|s|
# +-+-+-+-+-+
# |a|r|e| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e our', 'noise', ' uses', 'are  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |o|u|r|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |u|s|e|s|
# +-+-+-+-+-+
# |p|r|e| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e our', 'noise', ' uses', 'pre  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |o|u|r|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |u|s|e|d|
# +-+-+-+-+-+
# |a|r|e| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e our', 'noise', ' used', 'are  ']
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
# |e| |o|u|r|
# +-+-+-+-+-+
# |n|o|i|s|e|
# +-+-+-+-+-+
# | |u|s|e|d|
# +-+-+-+-+-+
# |p|r|e| | |
# +-+-+-+-+-+
#
# ['ten  ', 'e our', 'noise', ' used', 'pre  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |l|e|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e are', 'names', ' rest', 'les  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |r|e|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e are', 'names', ' rest', 'res  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e are', 'names', ' rest', 'yes  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |l|e|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' need', 'les  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |r|e|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' need', 'res  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' need', 'yes  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' need', 'ten  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |m|e|n| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' need', 'men  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |n|e|e|d|
# +-+-+-+-+-+
# |b|e|n| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' need', 'ben  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |i|s|o|
# +-+-+-+-+-+
# |n|o|v|e|l|
# +-+-+-+-+-+
# | |l|e|a|d|
# +-+-+-+-+-+
# |a|d|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e iso', 'novel', ' lead', 'ads  ']
# +-+-+-+-+-+
# |t|a|g| | |
# +-+-+-+-+-+
# |e| |a|r|e|
# +-+-+-+-+-+
# |n|a|m|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['tag  ', 'e are', 'names', ' rest', 'its  ']
# +-+-+-+-+-+
# |f|l|y| | |
# +-+-+-+-+-+
# |l| |a|n|n|
# +-+-+-+-+-+
# |y|a|h|o|o|
# +-+-+-+-+-+
# | |d|o|w|n|
# +-+-+-+-+-+
# |i|s|o| | |
# +-+-+-+-+-+
#
# ['fly  ', 'l ann', 'yahoo', ' down', 'iso  ']
# +-+-+-+-+-+
# |f|l|y| | |
# +-+-+-+-+-+
# |l| |a|n|d|
# +-+-+-+-+-+
# |y|a|h|o|o|
# +-+-+-+-+-+
# | |d|o|w|n|
# +-+-+-+-+-+
# |i|s|o| | |
# +-+-+-+-+-+
#
# ['fly  ', 'l and', 'yahoo', ' down', 'iso  ']
# +-+-+-+-+-+
# |f|l|y| | |
# +-+-+-+-+-+
# |l| |a|l|l|
# +-+-+-+-+-+
# |y|a|h|o|o|
# +-+-+-+-+-+
# | |d|o|g|s|
# +-+-+-+-+-+
# |i|s|o| | |
# +-+-+-+-+-+
#
# ['fly  ', 'l all', 'yahoo', ' dogs', 'iso  ']
# +-+-+-+-+-+
# |f|l|y| | |
# +-+-+-+-+-+
# |l| |a|r|m|
# +-+-+-+-+-+
# |y|a|h|o|o|
# +-+-+-+-+-+
# | |d|o|w|n|
# +-+-+-+-+-+
# |i|s|o| | |
# +-+-+-+-+-+
#
# ['fly  ', 'l arm', 'yahoo', ' down', 'iso  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |i|r|o|n|
# +-+-+-+-+-+
# |a|r|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' iron', 'are  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |i|r|o|n|
# +-+-+-+-+-+
# |p|r|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' iron', 'pre  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |t|a|b|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |i|r|o|n|
# +-+-+-+-+-+
# |a|r|t| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o tab', 'usage', ' iron', 'art  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|r|e|a|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' area', 'one  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|s|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|r|e|a|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o has', 'usage', ' area', 'one  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |t|a|b|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|g|e|d|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o tab', 'usage', ' aged', 'one  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |i|r|o|n|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' iron', 'one  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |u|p|o|n|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' upon', 'one  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |o|p|e|n|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' open', 'one  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |t|a|b|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |i|r|o|n|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o tab', 'usage', ' iron', 'its  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|t|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|r|e|a|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o hat', 'usage', ' area', 'eye  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |h|a|s|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|r|e|a|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o has', 'usage', ' area', 'eye  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |t|a|b|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|g|e|d|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o tab', 'usage', ' aged', 'eye  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |c|a|n|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |p|l|o|t|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o can', 'usage', ' plot', 'eye  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |c|a|m|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |p|l|o|t|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o cam', 'usage', ' plot', 'eye  ']
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
# |o| |c|a|p|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |p|l|o|t|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['yes  ', 'o cap', 'usage', ' plot', 'eye  ']
# +-+-+-+-+-+
# |y|e|t| | |
# +-+-+-+-+-+
# |o| |r|a|m|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |i|c|o|n|
# +-+-+-+-+-+
# |i|n|k| | |
# +-+-+-+-+-+
#
# ['yet  ', 'o ram', 'usage', ' icon', 'ink  ']
# +-+-+-+-+-+
# |y|e|t| | |
# +-+-+-+-+-+
# |o| |a|g|o|
# +-+-+-+-+-+
# |u|r|b|a|n|
# +-+-+-+-+-+
# | |e|l|s|e|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['yet  ', 'o ago', 'urban', ' else', 'use  ']
# +-+-+-+-+-+
# |y|o|u| | |
# +-+-+-+-+-+
# |o| |s|a|w|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|g|e|d|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['you  ', 'o saw', 'usage', ' aged', 'one  ']
# +-+-+-+-+-+
# |y|o|u| | |
# +-+-+-+-+-+
# |o| |s|a|y|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|g|e|s|
# +-+-+-+-+-+
# |o|n|e| | |
# +-+-+-+-+-+
#
# ['you  ', 'o say', 'usage', ' ages', 'one  ']
# +-+-+-+-+-+
# |y|o|u| | |
# +-+-+-+-+-+
# |o| |s|a|w|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|g|e|d|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['you  ', 'o saw', 'usage', ' aged', 'eye  ']
# +-+-+-+-+-+
# |y|o|u| | |
# +-+-+-+-+-+
# |o| |s|a|y|
# +-+-+-+-+-+
# |u|s|a|g|e|
# +-+-+-+-+-+
# | |a|g|e|s|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['you  ', 'o say', 'usage', ' ages', 'eye  ']
# +-+-+-+-+-+
# |f|e|e| | |
# +-+-+-+-+-+
# |a| |a|l|l|
# +-+-+-+-+-+
# |t|h|r|e|e|
# +-+-+-+-+-+
# | |e|l|s|e|
# +-+-+-+-+-+
# |d|r|y| | |
# +-+-+-+-+-+
#
# ['fee  ', 'a all', 'three', ' else', 'dry  ']
# +-+-+-+-+-+
# |f|e|e| | |
# +-+-+-+-+-+
# |a| |a|l|l|
# +-+-+-+-+-+
# |t|h|r|e|e|
# +-+-+-+-+-+
# | |e|l|s|e|
# +-+-+-+-+-+
# |t|r|y| | |
# +-+-+-+-+-+
#
# ['fee  ', 'a all', 'three', ' else', 'try  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|r|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |a|r|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a war', 'twice', ' acts', 'are  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|r|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |p|r|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a war', 'twice', ' acts', 'pre  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|y|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |a|r|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a way', 'twice', ' acts', 'are  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|y|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |p|r|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a way', 'twice', ' acts', 'pre  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |r|a|y|
# +-+-+-+-+-+
# |t|r|a|d|e|
# +-+-+-+-+-+
# | |a|i|d|s|
# +-+-+-+-+-+
# |o|w|n| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a ray', 'trade', ' aids', 'own  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |e|y|e|
# +-+-+-+-+-+
# |t|a|x|e|s|
# +-+-+-+-+-+
# | |c|a|s|t|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a eye', 'taxes', ' cast', 'its  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|r|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a war', 'twice', ' acts', 'use  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|y|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a way', 'twice', ' acts', 'use  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|v|e|
# +-+-+-+-+-+
# |t|e|x|a|s|
# +-+-+-+-+-+
# | |s|e|n|t|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a ave', 'texas', ' sent', 'its  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |l|e|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'les  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |r|e|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'res  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'yes  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|x|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |l|e|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'taxes', ' rest', 'les  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|x|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |r|e|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'taxes', ' rest', 'res  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|x|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |y|e|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'taxes', ' rest', 'yes  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |t|e|n| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'ten  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |m|e|n| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'men  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |b|e|n| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'ben  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|r|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a war', 'twice', ' acts', 'eye  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |w|a|y|
# +-+-+-+-+-+
# |t|w|i|c|e|
# +-+-+-+-+-+
# | |a|c|t|s|
# +-+-+-+-+-+
# |e|y|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a way', 'twice', ' acts', 'eye  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|k|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'takes', ' rest', 'its  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |a|r|e|
# +-+-+-+-+-+
# |t|a|x|e|s|
# +-+-+-+-+-+
# | |r|e|s|t|
# +-+-+-+-+-+
# |i|t|s| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a are', 'taxes', ' rest', 'its  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |h|a|t|
# +-+-+-+-+-+
# |t|h|e|i|r|
# +-+-+-+-+-+
# | |a|r|m|y|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a hat', 'their', ' army', 'use  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |h|a|t|
# +-+-+-+-+-+
# |t|h|e|r|e|
# +-+-+-+-+-+
# | |a|r|e|a|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a hat', 'there', ' area', 'use  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |h|a|d|
# +-+-+-+-+-+
# |t|h|e|i|r|
# +-+-+-+-+-+
# | |a|r|m|y|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a had', 'their', ' army', 'use  ']
# +-+-+-+-+-+
# |f|i|t| | |
# +-+-+-+-+-+
# |a| |h|e|r|
# +-+-+-+-+-+
# |t|h|e|s|e|
# +-+-+-+-+-+
# | |a|r|t|s|
# +-+-+-+-+-+
# |u|s|e| | |
# +-+-+-+-+-+
#
# ['fit  ', 'a her', 'these', ' arts', 'use  ']

# %%
node_tracker
# Out:
# defaultdict(int,
#             {0: 1,
#              1: 4,
#              2: 34,
#              3: 7388,
#              4: 1617856,
#              5: 1434294,
#              6: 54818,
#              7: 46066,
#              8: 4848,
#              9: 233,
#              10: 100})

# %%
# +-+-+-+-+-+
# |h|a|r|s|h|
# +-+-+-+-+-+
# |a|m|a|t|i|
# +-+-+-+-+-+
# |l|i|d|a|r|
# +-+-+-+-+-+
# |a|g|i|l|e|
# +-+-+-+-+-+
# |b|o|x|e|r|
# +-+-+-+-+-+
